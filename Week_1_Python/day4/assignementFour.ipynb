# %% [markdown]
# # Assignment 4
# In this assignment we will use matplotlib and pandas to visualize data.
#
# To pass, you need to: !!!NOT DEFINED YET!!!
#
# You can either solve this assignment with the data we provide, or you can use your own data.
#
# !!! ADD PATH TO DATA - UPLOAD ON GITHUB? !!!

# %% [markdown]
# ## Part 1 Doctorates
# There is a lot of very interesting data about doctorates awarded in the US:

# %%
from IPython.display import Image
Image(filename=r"C:\Users\Mitsch\Documents\work\dayFour\chart.png")

# %%
Image(filename=r"C:\Users\Mitsch\Documents\work\dayFour\chart2.png")

# %%
Image(filename=r"C:\Users\Mitsch\Documents\work\dayFour\chart3.png")

# %% [markdown]
# *Image sources: *https://www.tylervigen.com/spurious-correlations

# %% [markdown]
# ### A) Bar plots
# Use the data in the file "doc.csv" to create a bar chart where the x-axis displays the type of doctorates ("Science and engineering" or "Non-"Science and engineering") and where the y-axis displays the total number of awarded doctorates in those categories.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 

#Your solution goes here

# %% [markdown]
# ### Solution
# *To be removed*

# %%
docs = pd.read_csv("doc.csv")
docs.head()
# Out:
#    Year  Science and engineering  Non-science and engineering
# 0  1999                    25931                        15167
# 1  2000                    25966                        15400
# 2  2001                    25529                        15208
# 3  2002                    24608                        15417
# 4  2003                    25283                        15476

# %%
docs.plot.bar(x = "Year")
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# ### B) Candlestick charts
# Modify your chart into a candlestick chart

# %% [markdown]
# ### C) Histogram

# %%
#your solution

# %%
docs["Science and engineering"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
docs["Science and engineering"].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### D) Scatterplot
# Modify the chart into 2 scatterplots - one for each category (S&E or non-S&E). Show how many doctorates were awarded over the years.

# %%
# your solution goes here

# %%
# Solution - to be removed
docs.plot.scatter(x = "Year", y = "Science and engineering")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Science and engineering'>

# %%
# Solution - to be removed
docs.plot.scatter(x = "Year", y = "Non-science and engineering")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Non-science and engineering'>

# %% [markdown]
# *Thoughts: Scatterplot does not look so good with so little data - maybe use dataset from seaborn?*

# %% [markdown]
# ## Part 2
